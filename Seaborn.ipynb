# %% [markdown]
# # Seaborn

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\hp\Desktop\RTRP\Data sets\DemographicData.csv")
df
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
df.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df.shape
# Out:
# (195, 5)

# %%
s=df.head(7)
s
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
e=sns.barplot(x='Internet users',y='Birth rate',data=s)
plt.show()

# %%
t=sns.barplot(x='Internet users',y='Birth rate',data=s,color='k')
plt.show()

# %%
h=sns.barplot(x='Internet users',y='Birth rate',data=s,color='yellow')
plt.show()

# %%
e=sns.barplot(x='Internet users',y='Birth rate',data=s,palette='viridis')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\3881288767.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   e=sns.barplot(x='Internet users',y='Birth rate',data=s,palette='viridis')

# %%
e=sns.barplot(x='Internet users',y='Birth rate',data=s,palette='rainbow')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\1771623095.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   e=sns.barplot(x='Internet users',y='Birth rate',data=s,palette='rainbow')

# %%
#count plot:
sns.countplot(x='Birth rate',data=s,palette='rainbow')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\3775912607.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Birth rate',data=s,palette='rainbow')

# %%
sns.countplot(y='Birth rate',data=s,palette='spring')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\3240303371.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Birth rate',data=s,palette='spring')

# %%
sns.countplot(x='Internet users',hue='Birth rate',data=s,palette='viridis')
plt.show()

# %%
s
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income

# %%
df
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
df['new']=df['Internet users']/2
df
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group    new
# 0            High income  39.45
# 1             Low income   2.95
# 2    Upper middle income   9.55
# ...

# %%
j=df.head(7)
j
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
#
#           Income Group    new
# 0          High income  39.45
# 1           Low income   2.95
# 2  Upper middle income   9.55
# 3  Upper middle income  28.60
# 4          High income  44.00
# 5          High income  29.95
# 6  Lower middle income  20.95

# %%
sns.distplot(j.new, bins=4, color='m')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14788\1553795501.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(j.new, bins=4, color='m')

# %%
df['Income Group'].value_counts()
# Out:
# Income Group
# High income            67
# Lower middle income    50
# Upper middle income    48
# Low income             30
# Name: count, dtype: int64

# %%
sns.scatterplot(x='Birth rate',y='Internet users',data=df)
plt.show()

# %%
sns.scatterplot(x='Birth rate',y='Internet users',data=df,hue='Income Group')
plt.show()

# %%
# lmplot: function is used to plot data and draw regression model fits across grids
sns.lmplot(x='Birth rate',y='Internet users',data=df)

# %%
sns.lmplot(x='Birth rate',y='Internet users', hue='Income Group', data=df, markers)
plt.show()
# Out:
#   Cell In[104], line 1
#     sns.lmplot(x='Birth rate',y='Internet users', hue='Income Group', data=df, markers)
#                                                                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
#box plot:
sns.boxplot(x='Income Group',y='Internet users',data=df)
plt.show()
